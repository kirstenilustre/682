# %% [markdown]
# ## Kirsten Ilustre
# ## April 6, 2020
# ## GEOG 682 Lab 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
crime = pd.read_csv(r"S:\682\Spring20\kilustre\Lab2\Lab2Data\Lab2\Crime_2017.csv")

# %%
crime
# Out:
#                                                 wkt_geom       CCN     DATE  \
# 0      Point (-77.02498381736047861 38.89981322477427...  17099955  6/12/17
# 1      Point (-77.07098904595119393 38.90769465590191...  17099960  6/12/17
# 2      Point (-77.04663978712287076 38.9091032074190295)  17099975  6/12/17
# 3      Point (-77.0097061689589566 38.96372943312384507)  17099979  6/12/17
# 4      Point (-77.02886695677204898 38.89523608044212...  17099985  6/12/17
# 5      Point (-77.01829165516194564 38.92204705397512...  17099996  6/12/17
# 6      Point (-77.04947342271367461 38.9052644847968665)  17100005  6/12/17
# 7      Point (-76.99130541227569324 38.93784873962781...  17100009  6/12/17
# 8      Point (-77.05081574253719623 38.89603033899959...  17100014  6/12/17
# 9      Point (-77.05756680414387461 38.90525176878495...  17100032  6/12/17
# 10     Point (-76.94089617859597752 38.90126030129675...  17100042  6/12/17
# ...

# %%
crime.columns
# Out:
# Index(['wkt_geom', 'CCN', 'DATE', 'SHIFT', 'METHOD', 'OFFENSE', 'BLOCK',
#        'XBLOCK', 'YBLOCK', 'WARD', 'ANC', 'DISTRICT', 'PSA', 'NEIGHBORHO',
#        'BLOCK_GROU', 'CENSUS_TRA', 'VOTING_PRE', 'LATITUDE', 'LONGITUDE',
#        'BID', 'START_DATE', 'END_DATE', 'OBJECTID'],
#       dtype='object')

# %%
crime_jan = crime[crime['DATE'].between('1/1/17','1/31/17')]

# %%
crime_jan_offense = crime_jan ['OFFENSE']

# %%
crime_jan_offense.count()
# Out:
# 2496

# %% [markdown]
# **Total number of crimes committed in January = 2496**

# %%
crime_d3 = crime[crime['DISTRICT'] == 3]

# %%
crime_d3_offense = crime_d3['OFFENSE']

# %%
crime_d3_offense.count()
# Out:
# 5434

# %% [markdown]
# **Total number of crimes committed in District 3 = 5434**

# %%
crime_d3auto = crime_d3[crime_d3['OFFENSE'] == 'THEFT F/AUTO']

# %%
crime_d3auto_offense = crime_d3auto['OFFENSE']

# %%
crime_d3auto_offense.count()
# Out:
# 2337

# %% [markdown]
# **Total number of thefts from autos committed in District 3 = 2337**

# %%
crime_d3auto
# Out:
#                                                 wkt_geom       CCN      DATE  \
# 5      Point (-77.01829165516194564 38.92204705397512...  17099996   6/12/17
# 25     Point (-77.02838381221395991 38.92673837334142...  17101162   6/14/17
# 26     Point (-77.01893433591266103 38.9103811591353832)  17101172   6/14/17
# 74     Point (-77.02299834734563433 38.92742418932692...  17095239    6/5/17
# 87     Point (-77.03026851788845875 38.91112646496354...  17095360    6/5/17
# 88     Point (-77.02963591053969594 38.91483806305230...  17095374    6/5/17
# 143    Point (-77.02963152748601772 38.90428929193632...  17197682  11/15/17
# 156    Point (-77.02972055163131415 38.9242607533666245)  17197848  11/15/17
# 184    Point (-77.02172975821008549 38.92742443210578...  17183717  10/23/17
# 188    Point (-77.03098929977888076 38.92475588141714...  17183774  10/23/17
# 195    Point (-77.02534918122002239 38.92229796913235...  17188327  10/30/17
# ...

# %%
x = crime_d3auto['XBLOCK']

# %%
y = crime_d3auto['YBLOCK']

# %%
plt.scatter(x,y)

# %% [markdown]
# **The function is not selecting the range of dates correctly in cell 7**

# %%
df = pd.read_csv(r"S:\682\Spring20\kilustre\Lab2\Lab2Data\Lab2\Environmental_Data_Deep_Moor_2013.csv")

# %%
df_week2 = df[df['date'].between('2013_01_08','2013_01_14')]

# %% [markdown]
# **This code begins the second week on 1/8/2013 and ends it on 1/14/2013. The example code ended the week on 1/15/2013 which counted for 8 days instead of 7.**
